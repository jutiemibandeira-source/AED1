# %%
base= float(input("Insira a base: "))
altura = float(input("Insira a altura: "))
area = base * altura
print("A área do quadrilátero é igual a: ",area)
# Out:
# Insira a base:  2
# Insira a altura:  4
# A área do quadrilátero é igual a:  8.0
