# %% [markdown]
# # Lista de exercícios AED1 - Parte 1

# %% [markdown]
# ### Exercício 0 - Faça um algoritmo para ler um número e mostrar se ele é par ou impar, positivo ou negativo.

# %%
n = float(input("Digite um número: "))
if n % 2 == 0:
    print(f"O número {n} é par")
else:
    print(f"O número {n} é ímpar")
if n > 0:
    print(f"O número {n} é positivo")
else:
    print(f"O número {n} é negativo")
# Out:
# Digite um número:  -21
# O número -21.0 é ímpar
# O número -21.0 é negativo

# %% [markdown]
# ### Exercício 1 - Faça um Programa que peça dois números e imprima o maior deles.

# %%
n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))
if n1 > n2:
    print(f"O número {n1} é maior que o número {n2}")
else:
    print(f"O número {n2} é maior que o número {n1}")
# Out:
# Digite o primeiro número:  22
# Digite o segundo número:  34
# O número 34.0 é maior que o número 22.0

# %% [markdown]
# ### Exercício 2 - Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

# %%
n = float(input("Digite um número para ver se é negativo ou positivo: "))
if n >= 0:
    print(f"O valor {n} é positivo")
else:
    print(f"O valor {n} é negativo")
# Out:
# Digite um número para ver se é negativo ou positivo:  -1
# O valor -1.0 é negativo

# %% [markdown]
# ### Exercício 3 - Faça um Programa que verifique se uma letra digitada é vogal ou consoante.

# %%
letra = str(input("Digite uma letra: ")).upper()
vogais = ("A","E","I","O","U")
if letra in vogais:
    print(f"A letra {letra} é uma vogal")
else:
    print(f"A letra {letra} não é vogal")
# Out:
# Digite uma letra:  t
# A letra T não é vogal

# %% [markdown]
# ### Exercício 4 - Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:
# ##### a. A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
# ##### b. A mensagem "Reprovado", se a média for menor do que sete;
# ##### c. A mensagem "Aprovado com Distinção", se a média for igual a dez.

# %%
n1 = float(input("Digite sua primeira nota: "))
n2 = float(input("Digite sua segunda nota: "))
media = (n1 + n2)/ 2 
if media == 10:
    print(f"Aprovado com distinção: a média das notas é de {media}")
elif media >= 7 and media < 10:
    print(f"Aprovado: a média das notas é de {media} ")
else:
    print(f"Reprovado: a média é igual a {media}")
# Out:
# Digite sua primeira nota:  2
# Digite sua segunda nota:  9
# Reprovado: a média é igual a 5.5

# %% [markdown]
# ### Exercício 5 - Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre pelo mais barato.

# %%
prod1 = float(input("Qual o valor do primeiro produto"))
prod2 = float(input("Qual o valor do segundo produto"))
prod3 = float(input("Qual o valor do terceiro produto")) 
if prod1 < prod2 and prod1 < prod3:
    menor_valor = prod1
    print(f"A melhor escolha é {menor_valor}")
elif prod2 < prod3 and prod2 < prod1:
    menor_valor = prod2
    print(f"A melhor escolha é {menor_valor}")
else:
    print(f"A melhor escolha é {menor_valor}")
# Out:
# Qual o valor do primeiro produto 5
# Qual o valor do segundo produto 7
# Qual o valor do terceiro produto 0999
# A melhor escolha é 5.0

# %% [markdown]
# ### Exercício 6 - Faça um Programa que leia três números e mostre-os em ordem decrescente.

# %%
n1 = float(input("Insira um número:"))
n2 = float(input("Insira um número:"))
n3 = float(input("Insira um número:"))
if n1 >= n2 and n1 >= n3:
    if n2 >= n3:
        print(n1, n2, n3)
    else:
        print(n1, n3, n2)
elif n2 >= n1 and n2 >= n3:
    if n1 >= n3:
        print(n2, n1, n3)
    else:
        print(n2, n3, n1)
else:
    if n1 >= n2:
        print(n3, n1, n2)
    else:
        print(n3, n2, n1)
# Out:
# Insira um número: 1
# Insira um número: 6
# Insira um número: 9
# 9.0 6.0 1.0

# %% [markdown]
# ### Exercício 7 - Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno.
# Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %%
periodo = input("Qual período você estuda? [M/V/N]").upper()
if periodo == "N":
    print("Boa Noite!!")
elif periodo == "V":
    print("Boa Tarde!!")
else:
    print("Bom Dia!!")
# Out:
# Qual período você estuda? [M/V/N] m
# Bom Dia!!

# %% [markdown]
# ### Exercício 8 - As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contraram para desenvolver o programa que calculará os reajustes.
# #### a. Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no  salário atual:
#
# #### b. salários até R$ 280,00 (incluindo) : aumento de 20%
#
# #### c. salários entre R$ 280,00 e R$ 700,00 : aumento de 15%
#
# #### d. salários entre R$ 700,00 e R$ 1500,00 : aumento de 10%
#
# #### e. salários de R$ 1500,00 em diante : aumento de 5% Após o aumento ser realizado, informe na tela:
#
# #### f. o salário antes do reajuste;
#
# #### g. o percentual de aumento aplicado;
#
# #### h. o valor do aumento;
#
# #### i. o novo salário, após o aumento.

# %%
sal = float(input("Digite qual o seu salário:"))
if sal <= 280:
    nov_sal = sal * 1.2
elif sal >= 281 and sal <= 700:
    nov_sal = sal * 1.15
elif sal >= 701 and sal <= 1500:
    nov_sal = 1.1 * sal
elif sal > 1500:
    nov_sal = 1.05 * sal
print(f"O salário antigo é de: {sal}")
print(f"O percentual de aumento é de: {((nov_sal - sal)/sal)* 100 }")
print(f"O valor de aumento {nov_sal - sal}")
# Out:
# Digite qual o seu salário: 1000
# O salário antigo é de: 1000.0
# O percentual de aumento é de: 10.0
# O valor de aumento 100.0

# %% [markdown]
# ### Exercício 9 - Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que depende do salário bruto (conforme tabela abaixo) e 3% para o Sindicato e que o FGTS corresponde a 11% do Salário Bruto, mas não é descontado (é a empresa que deposita). O Salário Líquido corresponde ao Salário Bruto menos os descontos. O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.

# %% [markdown]
# ##### a. Desconto do IR:
#
# ##### b. Salário Bruto até 900 (inclusive) - isento
#
# ##### c. Salário Bruto até 1500 (inclusive) - desconto de 5%
#
# ##### d. Salário Bruto até 2500 (inclusive) - desconto de 10%
#
# ##### e. Salário Bruto acima de 2500 - desconto de 20% Imprima na tela as informações, dispostas conforme o exemplo
#
# ##### abaixo. No exemplo o valor da hora é 5 e a quantidade de hora é 220

# %%
valor_hora = float(input("Qual o valor da hora trabalhada?:  "))
total_horas = float(input("Qual o total de horas trabalhadas no mês?:"))
sal_bruto = valor_hora * total_horas
fgts = sal_bruto * 0.11
sindicato = sal_bruto * 0.03
if sal_bruto <= 900:
    a_ir = 0
elif sal_bruto <= 1500:
    a_ir = 0.05
elif sal_bruto <= 2500:
    a_ir = 0.1
else: 
    a_ir = 0.2
ir = sal_bruto * a_ir
sal_liq = sal_bruto - (sindicato + ir)
print("Demonstrativo Salarial")
print("=================================")
print(f"Salário Bruto: R${sal_bruto:8.2f}")
print(f"Taxa Sindical: R${sindicato:8.2f}")
print(f"Desconto IR: R${ir:8.2f}")
print(f"Desconto FGTS: R${fgts:8.2f}")
# Out:
# Qual o valor da hora trabalhada?:   10
# Qual o total de horas trabalhadas no mês?: 1000
# Demonstrativo Salarial
# =================================
# Salário Bruto: R$10000.00
# Taxa Sindical: R$  300.00
# Desconto IR: R$ 2000.00
# Desconto FGTS: R$ 1100.00

# %% [markdown]
# ### 10 - Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule
# a sua média. A atribuição de conceitos obedece à tabela abaixo:

# %% [markdown]
# ##### a.   Média de Aproveitamento  Conceito
#
# ##### b.   Entre 9.0 e 10.0        A
#
# ##### c.   Entre 7.5 e 9.0         B
#
# ##### d.   Entre 6.0 e 7.5         C
#
# ##### e.   Entre 4.0 e 6.0         D
#
# ##### f.   Entre 4.0 e zero        E

# %%
n1 = float(input("Digite sua primeira nota: "))
n2 = float(input("Digite sua segunda nota: "))
media = (n1 + n2)/ 2 
if media <= 10.0 and media >= 9.1:
    print(f"A: a média das notas é de {media}")
elif media <= 9.0 and media >= 7.6:
    print(f"B: a média das notas é de {media} ")
elif media <= 7.5  and media >= 6.1:
    print(f"C: a média das notas é de {media} ")
elif media <= 6.0 and media >= 4.1:
    print(f"C: a média das notas é de {media} ")
else:
    print(f"E: a média é igual a {media}")
# Out:
# Digite sua primeira nota:  10
# Digite sua segunda nota:  7
# B: a média das notas é de 8.5
