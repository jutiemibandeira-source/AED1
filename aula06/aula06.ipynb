# %%
idade = int(input("Qual sua idade? "))
carro = input("Você possui carro? S/N ").upper()
if (idade >=18) and (carro == "S"):
    print("Pode dirigir!")
else:
    print("Chame um uber!")
# Out:
# Qual sua idade?  1
# Você possui carro? S/N  3
# Chame um uber!

# %%
idade= int(input("Qual sua idade: "))
if idade>= 18:
    carro= input("Você possui carro?: S/N").upper()
    if carro == "S":
        print("Pode dirigir!!")
    else:
        print("Chama o uber!")
else:
    print("Chama o uber!!")
# Out:
# Qual sua idade:  1
# Chama o uber!!

# %%
nota1 = float(input("Insira sua primeira nota: "))
nota2 = float(input("Insira sua segunda nota: "))
media = (nota1 + nota2)/2 
print(f"Sua média é igual a {media}")
if media >=5:
    print("Aprovado")
else:
    print("Reprovado")

# %%
nota1 = float(input("Insira sua primeira nota: "))
if nota1 >=7:
    nota1 += nota1 + 0.5
nota2 = float(input("Insira sua segunda nota: "))
if nota2 >=7:
    nota2 += 0.5
media = (nota1 + nota2)/2 
print(f"Sua média é igual a {media}")
if media >=5:
    print("Aprovado")
else:
    print("Reprovado")

# %%
a = float(input("Insira o primeiro lado do triângulo"))
b = float(input("insira o segundo lado do triângulo"))
c = float(input("insira o terceiro lado do triângulo"))
if (a + b > c) and (a + c > b) and (b + c > a):
    if a == c == a == b:  
        print("Seu triângulo é equilátero")
    elif a != b != c:
        print("Seu triângulo é escaleno")
    else:
        print("Seu triângulo é isósceles")
else:
    print("Suas medidas não podem formar um triângulo!!")
